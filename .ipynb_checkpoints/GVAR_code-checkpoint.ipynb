# %% [markdown]
# # Global VAR code

# %%
# Imports
import numpy as np
import pandas as pd
import sklearn.metrics as skm
from statsmodels.tsa.vector_ar.var_model import VAR
import statsmodels.tsa.vector_ar.vecm
import statsmodels.api as sm
import seaborn as sns
from matplotlib import pyplot as plt
import openpyxl

# %%
# Define your path
path = "/Users/v.d Bosch/Documents/Github/GVAR_modelling/"

# %% [markdown]
# # Loading data

# %%
# Get a list of all countries
country_list = openpyxl.load_workbook(path + "Country_data.xlsx").sheetnames

# Initialize DataFrame about variables per country
df_country = pd.read_excel(path + "Country_data.xlsx",index_col=0, sheet_name=country_list)
country_list = np.array(country_list)

# Define variable lists
dom_variable_list = np.array(['y','Dp','eq','ep','r','lr'])
for_variable_list = np.array(['ys','Dps','eqs','eps','rs','lrs'])
variable_list = np.array(['y','Dp','eq','ep','r','lr','ys','Dps','eqs','eps','rs','lrs'])
ext_variable_list = np.array(['Real gross domestic product','Inflation rate','Real equity price index','Real exchange rate','Short-term interest rate','Long-term interest rate'])

# Initialize dictionary about domestic and foreign variables
df_dom = {}
df_for = {}

# Initialize DataFrame about data availability
set_variables = pd.DataFrame(index=variable_list)

# Fill in these DataFrames
for country in country_list:
    df_country[country].index = pd.date_range('1979-04','2020', freq='Q')

    domestic_cols = [col for col in df_country[country].columns if not col.endswith("s")]
    df_dom[country] = df_country[country].loc[:,domestic_cols]
    
    foreign_cols = [col for col in df_country[country].columns if col.endswith("s")]
    df_for[country] = df_country[country].loc[:,foreign_cols]
    
    for variable in variable_list:
        if np.isin(variable, df_country[country].columns):
            set_variables.loc[variable,country] = True
        else:
            set_variables.loc[variable,country] = False

# %%
# Initialize DataFrame about trade data
year_list = ['2014','2015','2016']
df_trade = pd.read_excel(path + "Trading_data.xlsx",index_col=0, sheet_name=year_list)

# Create weighted trade weights
df_weights = (df_trade['2014'] + df_trade['2015'] + df_trade['2016'])/3
df_weights.fillna(0, inplace=True)

# Normalize the weights such that it sums to 1
for country in country_list:
    df_weights.loc[country] = df_weights.loc[country] / (df_weights.loc[country].sum())
    
# Initialize DataFrame about continent data
continent_list = ["North America","South America","Europe","Africa","Asia","Oceania"]
df_continent = pd.read_excel(path + "Continent_weights.xlsx",index_col=0, sheet_name=continent_list)

# %%
# Define extra variables
dom_variables = np.array([])

for country in country_list:
    for variable in dom_variable_list:
        if set_variables[country][variable]:
            dom_variables = np.append(dom_variables,[str(variable)+"_"+str(country)])

for_variables = np.array([])

for country in country_list:
    for variable in for_variable_list:
        if set_variables[country][variable]:
            for_variables = np.append(for_variables,[str(variable)+"_"+str(country)])

k_i = {}
k_star = {}
k = 0

for country in country_list:
    k_i[country] = set_variables[country][dom_variable_list].sum()
    k_star[country] = set_variables[country][for_variable_list].sum()
    k += k_i[country]

# %%
# Potentially save this trade matrix
# df_weights.to_excel(path + "saved_values.xlsx")

# Show the chosen trade matrix
df_weights
# Out:
#                 Argentina  Australia   Austria   Belgium    Brazil    Canada  \
# Argentina        0.000000   0.008665  0.002063  0.007553  0.265504  0.019327
# Australia        0.002311   0.000000  0.003191  0.006511  0.003865  0.008153
# Austria          0.001077   0.004666  0.000000  0.023828  0.003943  0.006292
# Belgium          0.001380   0.004665  0.009805  0.000000  0.009555  0.008159
# Brazil           0.083325   0.004864  0.003656  0.016222  0.000000  0.015844
# Canada           0.002178   0.003611  0.002098  0.005405  0.005994  0.000000
# China            0.005259   0.045174  0.003025  0.009534  0.029807  0.019124
# Chile            0.031073   0.007480  0.002896  0.010668  0.077263  0.018019
# Finland          0.001977   0.006114  0.013680  0.043957  0.009925  0.011597
# France           0.001874   0.004305  0.012510  0.114731  0.009202  0.007205
# Germany          0.002431   0.006346  0.063111  0.063724  0.009795  0.008076
# India            0.006710   0.029723  0.002911  0.034896  0.020614  0.013270
# Indonesia        0.006171   0.035352  0.001426  0.006505  0.014241  0.009022
# Italy            0.003628   0.007473  0.031022  0.054892  0.013089  0.009738
# Japan            0.001589   0.049735  0.002581  0.007588  0.011382  0.017215
# Korea            0.002155   0.037256  0.002911  0.005142  0.014460  0.012807
# Malaysia         0.004251   0.039920  0.002305  0.005206  0.008445  0.004794
# Mexico           0.003273   0.002071  0.001840  0.003566  0.011625  0.027940
# Netherlands      0.002884   0.005083  0.011200  0.126882  0.012608  0.006658
# New Zealand      0.001125   0.002405  0.005386  0.041626  0.012269  0.015730
# Norway           0.002543   0.173700  0.002970  0.006695  0.003083  0.014413
# Peru             0.018551   0.004499  0.001930  0.012266  0.052302  0.045683
# Philippines      0.003637   0.013279  0.001639  0.006371  0.003946  0.008549
# Saudi Arabia     0.007500   0.015581  0.005564  0.029218  0.017444  0.007915
# Singapore        0.002123   0.006157  0.003436  0.016999  0.013876  0.014484
# South Africa     0.000712   0.031653  0.002399  0.013630  0.005551  0.003966
# Spain            0.006851   0.005216  0.011171  0.043541  0.015199  0.006420
# Sweden           0.001481   0.008175  0.013977  0.058993  0.007202  0.007242
# Switzerland      0.003856   0.007091  0.036046  0.024178  0.007933  0.010700
# Thailand         0.004312   0.044038  0.001828  0.007702  0.011637  0.007142
# Turkey           0.002135   0.005394  0.013031  0.029343  0.011082  0.008759
# United Kingdom   0.001510   0.011631  0.008340  0.058246  0.008005  0.023105
# United States    0.004385   0.011067  0.004699  0.016730  0.019885  0.187709
#
#                    China     Chile   Finland    France  ...  South Africa  \
# Argentina       0.167736  0.034908  0.002260  0.019450  ...      0.009254
# Australia       0.316774  0.002678  0.001977  0.013372  ...      0.004478
# Austria         0.039477  0.001176  0.004669  0.046809  ...      0.003370
# Belgium         0.037591  0.001911  0.007168  0.155654  ...      0.006535
# Brazil          0.228286  0.026367  0.003118  0.024419  ...      0.006013
# Canada          0.085512  0.002731  0.001779  0.009769  ...      0.001506
# China           0.000000  0.012846  0.002974  0.020563  ...      0.016752
# Chile           0.283972  0.000000  0.003968  0.026821  ...      0.001712
# Finland         0.056813  0.004494  0.000000  0.043882  ...      0.005830
# France          0.056643  0.002033  0.004769  0.000000  ...      0.003320
# Germany         0.090967  0.002076  0.010748  0.111456  ...      0.008802
# India           0.170668  0.006951  0.003103  0.020538  ...      0.024236
# Indonesia       0.179193  0.001236  0.002327  0.008914  ...      0.004848
# Italy           0.068518  0.003616  0.005206  0.136653  ...      0.006214
# Japan           0.272674  0.007869  0.001793  0.015647  ...      0.007401
# Korea           0.311651  0.008526  0.002038  0.012293  ...      0.003715
# Malaysia        0.188848  0.001099  0.000948  0.013425  ...      0.004183
# Mexico          0.103782  0.004526  0.000914  0.007825  ...      0.000000
# Netherlands     0.093785  0.002771  0.011393  0.079504  ...      0.005826
# New Zealand     0.068326  0.001616  0.020806  0.061725  ...      0.002204
# Norway          0.223757  0.003031  0.002210  0.019133  ...      0.004171
# Peru            0.256044  0.038280  0.003785  0.009554  ...      0.002131
# Philippines     0.176575  0.000750  0.002172  0.018249  ...      0.001516
# Saudi Arabia    0.202475  0.001666  0.004285  0.026567  ...      0.000000
# Singapore       0.177493  0.000534  0.001980  0.022129  ...      0.018610
# South Africa    0.179317  0.000325  0.000951  0.022971  ...      0.002985
# Spain           0.062248  0.007168  0.005375  0.195274  ...      0.005362
# Sweden          0.062478  0.002336  0.077335  0.057564  ...      0.005019
# Switzerland     0.076273  0.002052  0.003874  0.077177  ...      0.005796
# Thailand        0.199157  0.002864  0.001725  0.013147  ...      0.009624
# Turkey          0.133138  0.002383  0.006396  0.066580  ...      0.007403
# United Kingdom  0.097350  0.001838  0.006351  0.074512  ...      0.012619
# United States   0.186404  0.007616  0.002046  0.025101  ...      0.004106
#
#                 Saudi Arabia  Singapore     Spain    Sweden  Switzerland  \
# Argentina           0.008480   0.002860  0.027472  0.003595     0.016839
# Australia           0.005235   0.038743  0.007230  0.005583     0.009138
# Austria             0.004741   0.002215  0.020448  0.013495     0.076398
# Belgium             0.006234   0.011449  0.027966  0.021245     0.016505
# Brazil              0.016003   0.011189  0.021386  0.005999     0.014832
# Canada              0.003504   0.002454  0.003732  0.002460     0.005817
# China               0.021652   0.030529  0.010953  0.005268     0.013094
# Chile               0.001863   0.001324  0.024979  0.004681     0.008171
# Finland             0.004492   0.003190  0.024368  0.184213     0.014717
# France              0.012125   0.009685  0.088556  0.014867     0.039569
# Germany             0.006056   0.005724  0.041455  0.023977     0.057083
# India               0.078037   0.037074  0.012116  0.005379     0.048444
# Indonesia           0.023267   0.125779  0.008268  0.003037     0.006888
# Italy               0.014889   0.004069  0.069395  0.013790     0.054433
# Japan               0.035908   0.027005  0.006111  0.003345     0.010018
# Korea               0.044088   0.035768  0.006353  0.003406     0.004628
# Malaysia            0.010657   0.160296  0.003565  0.002736     0.007795
# Mexico              0.000761   0.002629  0.011930  0.001564     0.004240
# Netherlands         0.008304   0.010927  0.029960  0.023753     0.011877
# New Zealand         0.000951   0.011637  0.021213  0.100997     0.009270
# Norway              0.014785   0.032588  0.008439  0.004394     0.005103
# Peru                0.002534   0.001570  0.030112  0.005341     0.043222
# Philippines         0.020604   0.082217  0.005166  0.002061     0.006050
# Saudi Arabia        0.042380   0.016164  0.021524  0.010046     0.017838
# Singapore           0.000000   0.037759  0.019733  0.005214     0.010713
# South Africa        0.022566   0.000000  0.002609  0.002440     0.012088
# Spain               0.017581   0.002392  0.000000  0.012509     0.019854
# Sweden              0.006564   0.003956  0.021944  0.000000     0.012623
# Switzerland         0.009857   0.022397  0.024074  0.006991     0.000000
# Thailand            0.026149   0.050415  0.004534  0.003734     0.023266
# Turkey              0.025696   0.003604  0.051149  0.014147     0.034334
# United Kingdom      0.009997   0.009606  0.040640  0.020556     0.052076
# United States       0.015028   0.014581  0.007679  0.004421     0.017609
#
#                 Thailand    Turkey  United Kingdom  United States
# Argentina       0.015505  0.006432        0.014731       0.127333
# Australia       0.041637  0.003134        0.026847       0.096530
# Austria         0.003128  0.013682        0.032727       0.056016
# Belgium         0.004056  0.014505        0.083659       0.083658
# Brazil          0.011925  0.006638        0.020398       0.182179
# Canada          0.003997  0.002522        0.025182       0.688913
# China           0.029636  0.008466        0.030890       0.214996
# Chile           0.009313  0.005000        0.011791       0.180274
# Finland         0.003754  0.012743        0.057408       0.065657
# France          0.004289  0.016234        0.070185       0.077206
# Germany         0.005214  0.021954        0.080237       0.094935
# India           0.021114  0.014423        0.033471       0.150615
# Indonesia       0.055294  0.006684        0.009433       0.092135
# Italy           0.004749  0.029883        0.059609       0.086811
# Japan           0.047964  0.002895        0.017686       0.192420
# Korea           0.016262  0.009456        0.018250       0.157439
# Malaysia        0.070394  0.004635        0.013058       0.106129
# Mexico          0.007442  0.001303        0.006381       0.675361
# Netherlands     0.005852  0.011781        0.093756       0.069377
# New Zealand     0.004475  0.009179        0.182347       0.059749
# Norway          0.033646  0.003324        0.034535       0.131557
# Peru            0.010606  0.004187        0.013266       0.217652
# Philippines     0.065478  0.001241        0.008286       0.143513
# Saudi Arabia    0.024170  0.009354        0.052738       0.106178
# Singapore       0.025999  0.017432        0.018948       0.137829
# South Africa    0.043389  0.002032        0.018418       0.115194
# Spain           0.003282  0.025525        0.083672       0.056320
# Sweden          0.005166  0.013263        0.083330       0.066069
# Switzerland     0.012947  0.016550        0.106332       0.120388
# Thailand        0.000000  0.004166        0.019585       0.116971
# Turkey          0.007261  0.000000        0.078657       0.087005
# United Kingdom  0.006534  0.019304        0.000000       0.138381
# United States   0.012536  0.005678        0.035032       0.000000
#
# [33 rows x 33 columns]

# %% [markdown]
# # Plot variables

# %%
# Define a country
country = 'Germany'

# Set legend equal to True or False
legend = False
sns.set_palette("Set1")

# Plot x_it and x_star for every variable
for i in range(len(ext_variable_list)):
    if legend == False:
        if set_variables[country][variable_list[i]]:
            sns.lineplot(data=df_dom[country][variable_list[i]])
    
        if set_variables[country][variable_list[i]+"s"]:
            sns.lineplot(data=df_for[country][variable_list[i]+"s"])
    
        plt.xlabel("Time period")
        plt.ylabel(ext_variable_list[i])
        
        plt.show()
    else:
        
        fig, ax = plt.subplots()
        
        if set_variables[country][variable_list[i]]:
            sns.lineplot(data=df_dom[country][variable_list[i]],label='Domestic Variable')

        if set_variables[country][variable_list[i]+"s"]:
            sns.lineplot(data=df_for[country][variable_list[i]+"s"],label='Foreign Variable')

        
        plt.xlabel("Time period")
        plt.ylabel(ext_variable_list[i])
    
        pos = ax.get_position()
        ax.set_position([pos.x0, pos.y0, pos.width, pos.height])
        ax.legend(loc='upper right', bbox_to_anchor=(1.62, 1.21),prop={'size':14},ncol=2)

        plt.show()

# %% [markdown]
# # Test order of integration

# %%
# Define the DataFrames to fill the results in
adf_test_diff0 = pd.DataFrame(index=dom_variable_list)
adf_test_diff1 = pd.DataFrame(index=dom_variable_list)
adf_test_diff2 = pd.DataFrame(index=dom_variable_list)

# Loop over every country and variable
for country in country_list:
    for variable in dom_variable_list:
        if set_variables[country][variable]:
            # Take the data and its first and second difference
            non_dif = df_dom[country][variable]
            first_dif = np.diff(non_dif)
            second_dif = np.diff(first_dif)
        
            # Fill the DataFrames with the adf test statistics
            adf_test_diff0.loc[variable,country] = round(sm.tsa.stattools.adfuller(non_dif, autolag= 'AIC',regression='ct')[0],4)
            adf_test_diff1.loc[variable,country] = round(sm.tsa.stattools.adfuller(first_dif, autolag= 'AIC',regression='ct')[0],4)
            adf_test_diff2.loc[variable,country] = round(sm.tsa.stattools.adfuller(second_dif, autolag= 'AIC',regression='ct')[0],4)

# %%
# Potentially save these unit root test results
# adf_test_diff0.to_excel(path + "saved_values.xlsx")

# Show the results
adf_test_diff0
# adf_test_diff1
# adf_test_diff2
# Out:
#     Argentina  Australia  Austria  Belgium  Brazil  Canada   China   Chile  \
# y     -2.7112    -2.0152  -1.4442  -1.7263 -2.7014 -1.9002 -1.3895 -0.6259
# Dp    -3.8487    -5.1946  -5.1901  -3.3029 -3.0838 -6.4637 -3.2316 -1.6412
# eq    -1.1557    -3.0223  -2.2023  -1.9544     NaN -3.0633     NaN -1.3558
# ep    -1.8670    -2.4804  -2.1061  -2.2777 -2.2198 -1.9379 -2.4084 -2.3263
# r     -3.5088    -2.6915  -3.4158  -4.2491 -3.3808 -3.1304 -2.3157 -2.1955
# lr        NaN    -3.7986  -3.3120  -3.8888     NaN -4.4628     NaN     NaN
#
#     Finland  France  ...  South Africa  Saudi Arabia  Singapore   Spain  \
# y   -2.3005 -1.3007  ...       -2.4955       -4.7248    -0.1144 -1.9520
# Dp  -3.0358 -5.0973  ...       -3.0856       -2.2694    -3.2290 -2.8009
# eq  -2.1940 -2.1708  ...       -4.5236           NaN    -4.6006 -1.7012
# ep  -2.3738 -2.1504  ...       -3.2659       -3.0649    -1.7124 -1.8742
# r   -3.1948 -3.1575  ...       -4.1708           NaN    -3.0229 -3.9527
# lr      NaN -3.2969  ...       -3.2926           NaN        NaN -2.6193
#
#     Sweden  Switzerland  Thailand  Turkey  United Kingdom  United States
# y  -3.6272      -3.3288   -0.9093 -3.1617         -1.8218        -1.4318
# Dp -4.0587      -2.9376   -7.0694 -2.0253         -4.4155        -5.3684
# eq -3.0325      -1.9456   -1.7371     NaN         -1.8823        -1.9782
# ep -2.1877      -2.3744   -2.1996 -1.5483         -2.0758            NaN
# r  -2.2658      -2.8160   -3.6393 -2.9235         -3.9945        -3.3167
# lr -5.2080      -3.6859       NaN     NaN         -3.9974        -4.2877
#
# [6 rows x 33 columns]

# %% [markdown]
# # Determine lag order

# %%
# Define maximum lag order
max_lag = 4

# Loop over all countries
for country in country_list:
    # Define the current lowest BIC value
    min_bic = 1000000
    
    # Loop over all possible combinations
    for lag_x_it in range(1,max_lag+1):
        for lag_x_star in range(1,max_lag+1):
    
            max_lag = max(lag_x_it,lag_x_star)
    
            x_it_star = pd.concat([df_dom[country],df_for[country]],axis=1)
    
            eigenvalues = statsmodels.tsa.vector_ar.vecm.coint_johansen(x_it_star,det_order=-1,k_ar_diff=max_lag-1).eig

            # Determine the rank of cointegration
            rank = np.sum(np.cumsum(eigenvalues) < 1)

            if (rank > k_i[country]):
                rank = k_i[country]

            coin_result = statsmodels.tsa.vector_ar.vecm.VECM(endog= df_dom[country][1:],exog=df_for[country].diff(1)[1:],exog_coint=df_for[country][1:],coint_rank=rank,k_ar_diff=max_lag-1).fit()
    
            # Initialize a dataframe with the x_star values of lag 0
            df_parameters = pd.concat([df_dom[country].shift(1),df_for[country].shift(1)], axis=1) @ np.vstack([coin_result.beta,coin_result.det_coef_coint])
            df_parameters.columns = ["_" + str(i) +"_coin" for i in range(coin_result.beta.shape[1])]

            # Initialize a dataframe with the x_star values of lag 0
            lagged_x_star = pd.concat([df_for[country].diff(1)],axis=1)
            lagged_x_star.columns += "_L0"
            df_parameters = pd.concat([df_parameters,lagged_x_star],axis=1)
            
            # Loop over all lag_x_it values to add the lagged values of x_it to df_parameters
            for lag in range(1,lag_x_it+1):
                if (lag <= lag_x_it-1):
                    lagged_x_it = df_dom[country].diff(1).shift(lag)
                    lagged_x_it.columns += "_dom_diff_L"+str(lag) 
                    df_parameters = pd.concat([df_parameters,lagged_x_it], axis=1)
            
            # Loop over all lag_x_star values to add the lagged values of x_star to df_parameters
            for lag in range(1,lag_x_star+1):
                if (lag <= lag_x_star-1):
                    lagged_x_star = df_for[country].diff(1).shift(lag)
                    lagged_x_star.columns += "_for_diff_L"+str(lag) 
                    df_parameters = pd.concat([df_parameters,lagged_x_star], axis=1)
        
            # Create and fit the model
            model = VAR(endog = df_dom[country].diff(1).iloc[max_lag:], exog = df_parameters.iloc[max_lag:])
            results = model.fit(maxlags=0,trend='ct',method='ols')
            
            # Update the lag and BIC value if the BIC value is smaller
            if (results.bic < min_bic):
                min_bic = results.bic
                best_lag_bic = (lag_x_it,lag_x_star)
            
    print("For",country)
    print("The lag order by BIC is",best_lag_bic)
    print("The BIC value is",min_bic)
    print("")
# Out:
# For Argentina
# The lag order by BIC is (2, 1)
# The BIC value is -24.129222056954735
#
# For Australia
# The lag order by BIC is (1, 1)
# The BIC value is -57.94341868777388
#
# For Austria
# The lag order by BIC is (1, 1)
# The BIC value is -60.997953730316205
#
# For Belgium
# The lag order by BIC is (1, 1)
# The BIC value is -61.316111640438265
#
# For Brazil
# The lag order by BIC is (2, 2)
# The BIC value is -23.852539604383757
#
# For Canada
# The lag order by BIC is (1, 2)
# The BIC value is -62.26893782538762
#
# For China
# The lag order by BIC is (2, 1)
# The BIC value is -38.06098168004256
#
# For Chile
# The lag order by BIC is (2, 1)
# The BIC value is -36.36904861592015
#
# For Finland
# The lag order by BIC is (1, 1)
# The BIC value is -43.78993607853252
#
# For France
# The lag order by BIC is (1, 1)
# The BIC value is -62.88051610020339
#
# For Germany
# The lag order by BIC is (1, 1)
# The BIC value is -62.61929663794917
#
# For India
# The lag order by BIC is (1, 1)
# The BIC value is -40.11222645505762
#
# For Indonesia
# The lag order by BIC is (3, 1)
# The BIC value is -30.44570810378159
#
# For Italy
# The lag order by BIC is (1, 1)
# The BIC value is -59.04374366897262
#
# For Japan
# The lag order by BIC is (1, 1)
# The BIC value is -59.34206450045458
#
# For Korea
# The lag order by BIC is (1, 1)
# The BIC value is -52.586170498635745
#
# For Malaysia
# The lag order by BIC is (1, 1)
# The BIC value is -43.5657113467753
#
# For Mexico
# The lag order by BIC is (2, 1)
# The BIC value is -30.760947394432804
#
# For Netherlands
# The lag order by BIC is (1, 1)
# The BIC value is -63.48455386540336
#
# For Norway
# The lag order by BIC is (1, 1)
# The BIC value is -56.15990167294127
#
# For New Zealand
# The lag order by BIC is (1, 1)
# The BIC value is -55.11597901723419
#
# For Peru
# The lag order by BIC is (4, 1)
# The BIC value is -23.736487108755497
#
# For Philippines
# The lag order by BIC is (1, 1)
# The BIC value is -37.946297288646484
#
# For South Africa
# The lag order by BIC is (2, 1)
# The BIC value is -55.3395011927958
#
# For Saudi Arabia
# The lag order by BIC is (2, 1)
# The BIC value is -29.272720124688327
#
# For Singapore
# The lag order by BIC is (1, 1)
# The BIC value is -44.054416849721434
#
# For Spain
# The lag order by BIC is (2, 1)
# The BIC value is -58.038874226801816
#
# For Sweden
# The lag order by BIC is (1, 1)
# The BIC value is -57.36748438378865
#
# For Switzerland
# The lag order by BIC is (1, 1)
# The BIC value is -61.870520905569116
#
# For Thailand
# The lag order by BIC is (1, 1)
# The BIC value is -39.21872153906806
#
# For Turkey
# The lag order by BIC is (1, 1)
# The BIC value is -28.218199330774688
#
# For United Kingdom
# The lag order by BIC is (2, 1)
# The BIC value is -61.19425173938097
#
# For United States
# The lag order by BIC is (1, 1)
# The BIC value is -53.118824024398485

# %% [markdown]
# # Determining the cointegrating relationships

# %%
# Loop over all countries
for country in country_list:
    # Define the chosen lag
    lag_x_it = 2
    lag_x_star = 1
    max_lag = max(lag_x_it,lag_x_star)
    
    x_it_star = pd.concat([df_dom[country],df_for[country]],axis=1)
    eigenvalues = statsmodels.tsa.vector_ar.vecm.coint_johansen(x_it_star,det_order=-1,k_ar_diff=max_lag-1).eig

    # Determine the rank of cointegration
    rank = np.sum(np.cumsum(eigenvalues) < 1)

    if (rank > k_i[country]):
        rank = k_i[country]
        
    print("For",country)
    print("The amount of cointegrating relationships is",rank)
    print("")
# Out:
# For Argentina
# The amount of cointegrating relationships is 2
#
# For Australia
# The amount of cointegrating relationships is 2
#
# For Austria
# The amount of cointegrating relationships is 2
#
# For Belgium
# The amount of cointegrating relationships is 2
#
# For Brazil
# The amount of cointegrating relationships is 2
#
# For Canada
# The amount of cointegrating relationships is 2
#
# For China
# The amount of cointegrating relationships is 2
#
# For Chile
# The amount of cointegrating relationships is 2
#
# For Finland
# The amount of cointegrating relationships is 2
#
# For France
# The amount of cointegrating relationships is 2
#
# For Germany
# The amount of cointegrating relationships is 2
#
# For India
# The amount of cointegrating relationships is 2
#
# For Indonesia
# The amount of cointegrating relationships is 2
#
# For Italy
# The amount of cointegrating relationships is 2
#
# For Japan
# The amount of cointegrating relationships is 2
#
# For Korea
# The amount of cointegrating relationships is 1
#
# For Malaysia
# The amount of cointegrating relationships is 2
#
# For Mexico
# The amount of cointegrating relationships is 2
#
# For Netherlands
# The amount of cointegrating relationships is 2
#
# For Norway
# The amount of cointegrating relationships is 2
#
# For New Zealand
# The amount of cointegrating relationships is 2
#
# For Peru
# The amount of cointegrating relationships is 2
#
# For Philippines
# The amount of cointegrating relationships is 1
#
# For South Africa
# The amount of cointegrating relationships is 2
#
# For Saudi Arabia
# The amount of cointegrating relationships is 2
#
# For Singapore
# The amount of cointegrating relationships is 2
#
# For Spain
# The amount of cointegrating relationships is 2
#
# For Sweden
# The amount of cointegrating relationships is 2
#
# For Switzerland
# The amount of cointegrating relationships is 2
#
# For Thailand
# The amount of cointegrating relationships is 2
#
# For Turkey
# The amount of cointegrating relationships is 2
#
# For United Kingdom
# The amount of cointegrating relationships is 2
#
# For United States
# The amount of cointegrating relationships is 2

# %% [markdown]
# # Period Analysis

# %% [markdown]
# ## Calculate GIRF

# %%
# Method to compute R_h for a given h
def calculate_R_h(h, F_l_dict,max_lag, memo={}):
    if h in memo:
        return memo[h]

    if h < 0:
        memo[h] = np.zeros((k,k))
    elif h == 0:
        memo[h] = np.eye(k)
    else:
        memo[h] = sum([F_l_dict[l] @ calculate_R_h(h-l, F_l_dict,max_lag) for l in range(1,max_lag+1)])
    
    return memo[h]

# %%
def create_G_j(j,df_estimates,lag_x_it,lag_x_star):
    
    # Define an empty collection of matrices
    matrix_col = []
    
    max_lag = max(lag_x_it,lag_x_star)
    # Loop over all countries
    for country in country_list:
        
        current_dom_variables = np.array(dom_variable_list)[set_variables.loc[dom_variable_list][country].tolist()]
        
        # Create E_i
        E_i = np.zeros((k_i[country],k))
        
        k_i_count = 0
        for variable in dom_variable_list:
            if set_variables[country][variable]:
                i = np.where(dom_variables == (str(variable)+"_"+str(country)))[0][0]
                E_i[k_i_count][i] = 1
                k_i_count += 1
        
        # Create W_i
        W_i = np.zeros((k_star[country],k))

        for W_country in country_list:

            k_i_count = 0
            
            for W_variable in for_variable_list:
                
                if (set_variables[W_country][W_variable[:-1]] and set_variables[country][W_variable]):
                    
                    i = np.where(dom_variables == (str(W_variable)[:-1]+"_"+str(W_country)))[0][0]
                    W_i[k_i_count][i] = df_weights[W_country][country]
                    k_i_count += 1
                
                elif (set_variables[country][W_variable]):
                    k_i_count += 1

        W_i = W_i / W_i.sum(1)[:,np.newaxis]
        
        # Create Omega_i
        Omega_i = np.vstack((E_i,W_i))

        # Create A_ij, depending on j
        if (j == 0):
            selected_cols = [col for col in df_estimates[country].columns if col.endswith("_L0")]
            
            lambda_i = df_estimates[country].loc[:,selected_cols]
            A_i = np.hstack((np.eye(k_i[country]),-lambda_i))

        else:
            
            if (lag_x_it < j):
                phi_i = np.zeros((k_i[country],k_i[country]))
            else:
                selected_cols = [col for col in df_estimates[country].columns if col.endswith("dom_L"+str(j))]
                phi_i = df_estimates[country].loc[:,selected_cols]
                
            if (lag_x_star < j):
                lambda_i = np.zeros((k_i[country],k_star[country]))
            else:
                selected_cols = [col for col in df_estimates[country].columns if col.endswith("for_L"+str(j))]
                lambda_i = df_estimates[country].loc[:,selected_cols]
                
            A_i = np.hstack((phi_i,lambda_i))
        

        # Finally, compute G_i by A_i and Omega_i

        G_i = A_i @ Omega_i
        
        matrix_col.append(G_i)
        
    # Return G_j
    return np.vstack(matrix_col)

# %%
def quick_perform_GIRF(df_dom_per, df_for_per, max_h,shock,variable_choice,min_y_axis,max_y_axis):
    df_estimates = {}
    resid_dict = {}

    # Define the chosen lag
    lag_x_it = 1
    lag_x_star = 1
    max_lag = max(lag_x_it,lag_x_star)
    
    for country in country_list:
        
        x_it_star = pd.concat([df_dom_per[country],df_for_per[country]],axis=1)

        eigenvalues = statsmodels.tsa.vector_ar.vecm.coint_johansen(x_it_star,det_order=-1,k_ar_diff=max_lag-1).eig

        # Determine the rank of cointegration
        rank = np.sum(np.cumsum(eigenvalues) < 1)

        if (rank > k_i[country]):
            rank = k_i[country]

        coin_result = statsmodels.tsa.vector_ar.vecm.VECM(endog= df_dom_per[country][1:],exog=df_for_per[country].diff(1)[1:],exog_coint=df_for_per[country][1:],coint_rank=rank,k_ar_diff=max_lag-1).fit()

        # Initialize a dataframe with the x_star values of lag 0
        df_parameters = pd.concat([df_dom_per[country].shift(1),df_for_per[country].shift(1)], axis=1) @ np.vstack([coin_result.beta,coin_result.det_coef_coint])
        df_parameters.columns = ["_" + str(i) +"_coin" for i in range(coin_result.beta.shape[1])]

        # Initialize a dataframe with the x_star values of lag 0
        lagged_x_star = pd.concat([df_for_per[country].diff(1)],axis=1)
        lagged_x_star.columns += "_L0"
        df_parameters = pd.concat([df_parameters,lagged_x_star],axis=1)

        # Loop over all lag_x_it values to add the lagged values of x_it to df_parameters
        for lag in range(1,lag_x_it+1):
            if (lag <= lag_x_it-1):
                lagged_x_it = df_dom_per[country].diff(1).shift(lag)
                lagged_x_it.columns += "_dom_diff_L"+str(lag) 
                df_parameters = pd.concat([df_parameters,lagged_x_it], axis=1)

        # Loop over all lag_x_star values to add the lagged values of x_star to df_parameters
        for lag in range(1,lag_x_star+1):
            if (lag <= lag_x_star-1):
                lagged_x_star = df_for_per[country].diff(1).shift(lag)
                lagged_x_star.columns += "_for_diff_L"+str(lag) 
                df_parameters = pd.concat([df_parameters,lagged_x_star], axis=1)

        # Create and fit the model
        model = VAR(endog = df_dom_per[country].diff(1).iloc[max_lag:], exog = df_parameters.iloc[max_lag:])
        results = model.fit(maxlags=0,trend='ct',method='ols')

        # Calculate the VARX* parameters from the VECM parameter estimates
        df_estimate =  results.params.T.loc[:,["const","trend"]]

        selected_cols = [col for col in results.params.T.columns if col.endswith("L0")]
        new_df = results.params.T.loc[:,selected_cols]
        new_df.columns = [str(variable) + "_L0" for variable in for_variable_list if set_variables[country][variable]]
        df_estimate = pd.concat([df_estimate,new_df],axis=1)

        selected_cols = [col for col in df_estimate.columns if col.endswith("_L0")]
        A_0 = np.hstack([np.eye(k_i[country]),-df_estimate.loc[:,selected_cols]])

        selected_cols = [col for col in results.params.T.columns if col.endswith("coin")] 
        new_df = results.params.T.loc[:,selected_cols] @ np.vstack([coin_result.beta,coin_result.det_coef_coint]).T
        new_df.columns = [str(variable) + "_dom_L1" for variable in dom_variable_list if set_variables[country][variable]] + [str(variable) + "_for_L1" for variable in for_variable_list if set_variables[country][variable]]
        df_estimate = pd.concat([df_estimate,new_df+A_0],axis=1)

        df_estimates[country] = df_estimate
        resid_dict[country] = results.resid

    # Stack all a_i0 parameters
    matrix_col = []
    for country in country_list:
        matrix_col.append(df_estimates[country].loc[:,"const"])
    a_0 = pd.concat(matrix_col)

    # Stack all a_i1 parameters
    matrix_col = []

    for country in country_list:
        matrix_col.append(df_estimates[country].loc[:,"trend"])
    a_1 = pd.concat(matrix_col)

    # Stack all residuals
    epsilon_t = pd.concat(resid_dict.values(), axis=1).T

    # Calculate the inverse of G_0
    G_0_inv = np.linalg.inv(create_G_j(0,df_estimates,lag_x_it,lag_x_star))

    # Create a dictionary for the values of F_l
    F_l_dict = {}
    memo = {}
    # Fill dictionary by computing the values of F_l 
    for j in range(max_lag+1):
        F_l_dict[j] = G_0_inv @ create_G_j(j,df_estimates,lag_x_it,lag_x_star)
    
    # Get the index of the country and variable of the shock and define e_j
    e_j = np.zeros((k,1))
    e_j[np.where(dom_variables == shock)[0][0]] = 1
    
    # Compute Sigma
    Sigma = np.cov(epsilon_t)

    # Calculate the GIRF for every h
    girf_matrix = np.hstack([calculate_R_h(h, F_l_dict,max_lag) @ G_0_inv @ Sigma @ e_j / np.sqrt(e_j.T @ Sigma @ e_j) for h in range(0,max_h+1)])
    
    fig, ax = plt.subplots()
    
    for continent in continent_list:
        weighted_GIRF = np.zeros(max_h+1)
        total_weights = 0
        
        continent_country_list = df_continent[continent].index
        for country in continent_country_list:
            if set_variables[country][variable_choice]:
                weighted_GIRF += girf_matrix[np.where(dom_variables == str(variable_choice)+"_"+str(country))[0][0]] * float(df_continent[continent].loc[country])
                total_weights += float(df_continent[continent].loc[country])
        
        weighted_GIRF = weighted_GIRF / total_weights

        min_y_axis = min(min_y_axis,np.min(weighted_GIRF))

        max_y_axis = max(max_y_axis,np.max(weighted_GIRF))
        
        i = 2
        
        if legend == True:
            sns.lineplot(x=np.arange(max_h+1),y=weighted_GIRF,label=continent)
            
            ax.set_xlabel("Horizon")
            ax.set_ylabel(ext_variable_list[i])
    
            pos = ax.get_position()
            ax.set_position([pos.x0, pos.y0, pos.width, pos.height])
            ax.legend(bbox_to_anchor=(1.065, 1.25),prop={'size':13},ncol=3)    
        else:
            sns.lineplot(x=np.arange(max_h+1),y=weighted_GIRF)
            ax.set_xlabel("Horizon")
            ax.set_ylabel(ext_variable_list[i])
            
    return fig, min_y_axis, max_y_axis

# %%
# Define the horizon
max_h =  24

# Define the variable + country where the shocks happens 
shock = "r_United States"
# Define the variable 
variable_choice = "y"

# Set the legend equal to True or False
legend = False

# Define the amount of GIRFs
amount_of_periods = 3

# Compute useful variables 
periods = len(df_country["Australia"].index)
interval = np.round(np.arange(0,periods+1,periods / amount_of_periods))
figures = []

# Define starting y-axis to reframe the plots
min_y_axis = 1000
max_y_axis = -1000

# Compute the variable 
for time in range(amount_of_periods):

    df_period = {}
    df_dom_per = {}
    df_for_per = {}

    for country in country_list:
        df_period[country] = df_country[country].iloc[int(interval[int(time)]):int(interval[int(time+1)])]
        
        domestic_cols = [col for col in df_period[country].columns if not col.endswith("s")]
        df_dom_per[country] = df_period[country].loc[:,domestic_cols]

        foreign_cols = [col for col in df_period[country].columns if col.endswith("s")]
        df_for_per[country] = df_period[country].loc[:,foreign_cols]

    fig, min_y_axis, max_y_axis = quick_perform_GIRF(df_dom_per, df_for_per, max_h,shock,variable_choice,min_y_axis,max_y_axis)
    figures.append(fig)

# Adjust the y-axis for all plots
for fig in figures:
    ax = fig.gca()
    ax.set_ylim(min_y_axis*1.16,max_y_axis*1.16)

# %% [markdown]
# # VECM

# %%
def perform_VECM_plot(df_dom_per,df_for_per,dep_variable_choice,ind_variable_choice,country):
    
    # Define the chosen lag
    lag_x_it = 1
    lag_x_star = 1
    max_lag = max(lag_x_it,lag_x_star)

    x_it_star = pd.concat([df_dom_per[country],df_for_per[country]],axis=1)

    eigenvalues = statsmodels.tsa.vector_ar.vecm.coint_johansen(x_it_star,det_order=-1,k_ar_diff=max_lag-1).eig

    # Determine the rank of cointegration
    rank = np.sum(np.cumsum(eigenvalues) < 1)

    if (rank > k_i[country]):
        rank = k_i[country]

    coin_result = statsmodels.tsa.vector_ar.vecm.VECM(endog= df_dom_per[country][1:],exog=df_for_per[country].diff(1)[1:],exog_coint=df_for_per[country][1:],coint_rank=rank,k_ar_diff=max_lag-1).fit()

    # Initialize a dataframe with the x_star values of lag 0
    df_parameters = pd.concat([df_dom_per[country].shift(1),df_for_per[country].shift(1)], axis=1) @ np.vstack([coin_result.beta,coin_result.det_coef_coint])
    df_parameters.columns = ["_" + str(i) +"_coin" for i in range(coin_result.beta.shape[1])]

    # Initialize a dataframe with the x_star values of lag 0
    lagged_x_star = pd.concat([df_for_per[country].diff(1)],axis=1)
    lagged_x_star.columns += "_L0"
    df_parameters = pd.concat([df_parameters,lagged_x_star],axis=1)

    # Loop over all lag_x_it values to add the lagged values of x_it to df_parameters
    for lag in range(1,lag_x_it+1):
        if (lag <= lag_x_it-1):
            lagged_x_it = df_dom_per[country].diff(1).shift(lag)
            lagged_x_it.columns += "_dom_diff_L"+str(lag) 
            df_parameters = pd.concat([df_parameters,lagged_x_it], axis=1)

    # Loop over all lag_x_star values to add the lagged values of x_star to df_parameters
    for lag in range(1,lag_x_star+1):
        if (lag <= lag_x_star-1):
            lagged_x_star = df_for_per[country].diff(1).shift(lag)
            lagged_x_star.columns += "_for_diff_L"+str(lag) 
            df_parameters = pd.concat([df_parameters,lagged_x_star], axis=1)

    # Create and fit the model
    model = VAR(endog = df_dom_per[country].diff(1).iloc[max_lag:], exog = df_parameters.iloc[max_lag:])
    results = model.fit(maxlags=0,trend='ct',method='ols')

    # Get the parameter and its theoretical confidence bounds
    parameter = results.params.T[ind_variable_choice].loc[dep_variable_choice]
    lower_bound = parameter - results.bse.T[ind_variable_choice].loc[dep_variable_choice] * 1.96
    upper_bound = parameter + results.bse.T[ind_variable_choice].loc[dep_variable_choice] * 1.96
    return (parameter,lower_bound,upper_bound)

# %%
# Choose the country which VARX* is estimated
country_choice = "Germany"

# Define window size and step size
period_len = 60
steps = 2
periods = len(df_country["Australia"].index)

# Define all parameters that are both domestic and foreign
dep_var_array = []
ind_var_array = []

for dom_variable in dom_variable_list:
    if set_variables[country_choice][dom_variable]:
        if set_variables[country_choice][dom_variable+"s"]:
            dep_var_array.append(dom_variable)
            ind_var_array.append(dom_variable+"s_L0")
            
# Go over all variables that are in dep_var_array
for dep_variable_choice in dep_var_array:

    print("Dependent variable:",dep_variable_choice)
    print("Independent variable:",dep_variable_choice+"s_L0")

    years = []
    parameters = []
    lower_bounds = []
    upper_bounds = []

    # For every time and variable, fit a VECM
    for time in np.arange(0,periods-period_len,steps):

        df_period = {}
        df_dom_per = {}
        df_for_per = {}

        for country in country_list:
            df_period[country] = df_country[country].iloc[time:period_len+time]

            domestic_cols = [col for col in df_period[country].columns if not col.endswith("s")]
            df_dom_per[country] = df_period[country].loc[:,domestic_cols]

            foreign_cols = [col for col in df_period[country].columns if col.endswith("s")]
            df_for_per[country] = df_period[country].loc[:,foreign_cols]

        years.append(df_period[country].index[-1])

        VECM_result = perform_VECM_plot(df_dom_per,df_for_per,dep_variable_choice,dep_variable_choice+"s_L0",country_choice)

        parameters.append(VECM_result[0])
        lower_bounds.append(VECM_result[1])
        upper_bounds.append(VECM_result[2])

    sns.lineplot(x=years,y=parameters,color='r')
    sns.lineplot(x=years,y=lower_bounds,linestyle="--",color='r',linewidth=0.8)
    sns.lineplot(x=years,y=upper_bounds,linestyle="--",color='r',linewidth=0.8)
    plt.xlabel("Last period")
    plt.ylabel("Parameter value")
    plt.show()
# Out:
# Dependent variable: y
# Independent variable: ys_L0
# Dependent variable: Dp
# Independent variable: Dps_L0
# Dependent variable: eq
# Independent variable: eqs_L0
# Dependent variable: r
# Independent variable: rs_L0
# Dependent variable: lr
# Independent variable: lrs_L0

# %%
def perform_VECM_RIER(df_dom_per,df_for_per,dep_variable_choice,ind_variable_choice,country):
    
    # Define the chosen lag
    lag_x_it = 1
    lag_x_star = 1
    max_lag = max(lag_x_it,lag_x_star)

    x_it_star = pd.concat([df_dom_per[country],df_for_per[country]],axis=1)

    eigenvalues = statsmodels.tsa.vector_ar.vecm.coint_johansen(x_it_star,det_order=-1,k_ar_diff=max_lag-1).eig

    # Determine the rank of cointegration
    rank = np.sum(np.cumsum(eigenvalues) < 1)

    if (rank > k_i[country]):
        rank = k_i[country]

    coin_result = statsmodels.tsa.vector_ar.vecm.VECM(endog= df_dom_per[country][1:],exog=df_for_per[country].diff(1)[1:],exog_coint=df_for_per[country][1:],coint_rank=rank,k_ar_diff=max_lag-1).fit()

    # Initialize a dataframe with the x_star values of lag 0
    df_parameters = pd.concat([df_dom_per[country].shift(1),df_for_per[country].shift(1)], axis=1) @ np.vstack([coin_result.beta,coin_result.det_coef_coint])
    df_parameters.columns = ["_" + str(i) +"_coin" for i in range(coin_result.beta.shape[1])]

    # Initialize a dataframe with the x_star values of lag 0
    lagged_x_star = pd.concat([df_for_per[country].diff(1)],axis=1)
    lagged_x_star.columns += "_L0"
    df_parameters = pd.concat([df_parameters,lagged_x_star],axis=1)

    # Loop over all lag_x_it values to add the lagged values of x_it to df_parameters
    for lag in range(1,lag_x_it+1):
        if (lag <= lag_x_it-1):
            lagged_x_it = df_dom_per[country].diff(1).shift(lag)
            lagged_x_it.columns += "_dom_diff_L"+str(lag) 
            df_parameters = pd.concat([df_parameters,lagged_x_it], axis=1)

    # Loop over all lag_x_star values to add the lagged values of x_star to df_parameters
    for lag in range(1,lag_x_star+1):
        if (lag <= lag_x_star-1):
            lagged_x_star = df_for_per[country].diff(1).shift(lag)
            lagged_x_star.columns += "_for_diff_L"+str(lag) 
            df_parameters = pd.concat([df_parameters,lagged_x_star], axis=1)

    # Create and fit the model
    model = VAR(endog = df_dom_per[country].diff(1).iloc[max_lag:], exog = df_parameters.iloc[max_lag:])
    results = model.fit(maxlags=0,trend='ct',method='ols')
    
    df_estimate =  results.params.T.loc[:,["const","trend"]]

    selected_cols = [col for col in results.params.T.columns if col.endswith("L0")]
    new_df = results.params.T.loc[:,selected_cols]
    new_df.columns = [str(variable) + "_L0" for variable in for_variable_list if set_variables[country][variable]]
    df_estimate = pd.concat([df_estimate,new_df],axis=1)

    selected_cols = [col for col in df_estimate.columns if col.endswith("_L0")]
    A_0 = np.hstack([np.eye(k_i[country]),-df_estimate.loc[:,selected_cols]])

    selected_cols = [col for col in results.params.T.columns if col.endswith("coin")] 
    new_df = results.params.T.loc[:,selected_cols] @ np.vstack([coin_result.beta,coin_result.det_coef_coint]).T
    new_df.columns = [str(variable) + "_dom_L1" for variable in dom_variable_list if set_variables[country][variable]] + [str(variable) + "_for_L1" for variable in for_variable_list if set_variables[country][variable]]
    df_estimate = pd.concat([df_estimate,new_df+A_0],axis=1)
    
    return df_estimate[ind_variable_choice].loc[dep_variable_choice]

# %%
# Define the new periods and step size
periods = len(df_country["Australia"].index)
period_len = 60
steps = 102

statistics = []

# Loop over all countries
for country_choice in country_list:
    dep_var_array = []
    ind_var_array = []

    # Include all domestic variables
    for dom_variable in dom_variable_list:
        if set_variables[country_choice][dom_variable]:
            dep_var_array.append(dom_variable)

    # Check the matrix Lambda 
    for for_variable in for_variable_list:
        if set_variables[country_choice][for_variable]:
            ind_var_array.append(for_variable+"_L0")

    # Check the matrix phi
#     for dom_variable in dom_variable_list:
#         if set_variables[country_choice][dom_variable]:
#             ind_var_array.append(dom_variable+"_dom_L1")
        
    # Get the RIER for every variable combination
    for dep_variable_choice in dep_var_array:
        for ind_variable_choice in ind_var_array:
            
            years = []
            parameters = []
            lower_bounds = []
            upper_bounds = []


            for time in np.arange(0,periods-period_len,steps):
                df_period = {}
                df_dom_per = {}
                df_for_per = {}

                for country in country_list:
                    df_period[country] = df_country[country].iloc[time:period_len+time]

                    domestic_cols = [col for col in df_period[country].columns if not col.endswith("s")]
                    df_dom_per[country] = df_period[country].loc[:,domestic_cols]

                    foreign_cols = [col for col in df_period[country].columns if col.endswith("s")]
                    df_for_per[country] = df_period[country].loc[:,foreign_cols]

                years.append(df_period[country].index[-1])

                VECM_result = perform_VECM_RIER(df_dom_per,df_for_per,dep_variable_choice,ind_variable_choice,country_choice)

                parameters.append(VECM_result)

            statistics.append((np.absolute(parameters[-1])-np.absolute(parameters[0]))/np.absolute(parameters[0]))
            
# Print the RIER for the following quantiles
quantile_array = [0.05,0.1,0.25,0.5,0.75,0.9,0.95]
for quantile in quantile_array:
    print(str(quantile)+" -> ",np.quantile(statistics,quantile))
# Out:
# 0.05 ->  -0.9596065281647321
# 0.1 ->  -0.9221172277362433
# 0.25 ->  -0.7118608277319285
# 0.5 ->  0.07204500793987823
# 0.75 ->  2.2275855695398734
# 0.9 ->  10.206166929531207
# 0.95 ->  23.675349999742764

# %% [markdown]
# end of code
